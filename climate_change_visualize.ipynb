# %% [markdown]
# # Effects of climate change on agriculture
#
# We'll be visualizing trends in food production across different countries since 1960s to 2020 to assess the impact of climate change on different food crops.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Introduction
# (will insert some introduction here)

# %% [markdown]
# ## Step 1: Downloading Data
# We have acquired our dataset from AgroSphere (a project under NASA), let us start visualizing the data on emmissions.
# We have 4 files (CSV) in the /data folder, as described:
# + countries.csv - Contains unique country codes which are used in emmissions and food production data
# + emissionAll.csv - Contains data from emissions from various sources (only agriculture.
# + FAOcrops.csv - Contains data from food productions (weight of crop in tonnes) of different countries.
# + yield.csv - Contains data from food productions (area of cultivated land in Ha) of different countries.

# %%
countries = pd.DataFrame(pd.read_csv('data/countries.csv'))
emissionall = pd.DataFrame(pd.read_csv('data/emissionAll.csv'))
cropsyield = pd.DataFrame(pd.read_csv('data/FAOcrops.csv'))
areayield = pd.DataFrame(pd.read_csv('data/yield.csv'))

# %% [markdown]
# ## Step 2: Cleaning and selecting the data
# The data is very big and unclean. It contains many information that we don't need so we'll be selecting only what we need and dropping the rest.

# %%
countries = countries.drop(['code2','Numeric code','lat','lon','iconCode'], axis=1)
countries.head(10)
# Out:
#                country code3
# 0              Albania   ALB
# 1              Algeria   DZA
# 2       American Samoa   ASM
# 3              Andorra   AND
# 4               Angola   AGO
# 5             Anguilla   AIA
# 6           Antarctica   ATA
# 7  Antigua and Barbuda   ATG
# 8            Argentina   ARG
# 9              Armenia   ARM

# %% [markdown]
# So, in the previous cell we removed all label that we didn't need and now we have only two columns - the country names and the code with us. This, looks good!

# %%
countryincludes = ['AFG','AUS','AUT','BGD','BRA','CHL','CHN','COG','FRA','GHA','IND','IDN','IRQ','JPN','JOR','MEX','NZL','KOR','REU','GBR','USA','VNM']
len(countryincludes)
# Out:
# 22

# %% [markdown]
# This is the list of countries only which we would be focusing the project on - 22 for now. Let us find the country in our data.

# %%
countries[countries.code3.isin(countryincludes)]
# Out:
#                 country code3
# 11            Australia   AUS
# 12              Austria   AUT
# 16           Bangladesh   BGD
# 28               Brazil   BRA
# 41                Chile   CHL
# 42                China   CHN
# 47                Congo   COG
# 71               France   FRA
# 79                Ghana   GHA
# 98                India   IND
# 99            Indonesia   IDN
# 101                Iraq   IRQ
# 107               Japan   JPN
# 109              Jordan   JOR
# 114  Korea, Republic of   KOR
# 139              Mexico   MEX
# 155         New Zealand   NZL
# 177             R'union   REU
# 227      United Kingdom   GBR
# 228       United States   USA
# 234            Viet Nam   VNM
# 242         Afghanistan   AFG

# %% [markdown]
# Now let us try our hands on the areayield dataset.
# Let us first know the crops (unique values) and then shall we select what we need to use in future.

# %%
cropsyield.typeName.unique()
# Out:
# array(['Almonds, with shell Production in tonnes',
#        'Anise, badian, fennel, coriander Production in tonnes',
#        'Apples Production in tonnes', 'Apricots Production in tonnes',
#        'Barley Production in tonnes', 'Berries nes Production in tonnes',
#        'Cotton lint Production in tonnes',
#        'Cottonseed Production in tonnes', 'Figs Production in tonnes',
#        'Fruit, citrus nes Production in tonnes',
#        'Fruit, fresh nes Production in tonnes',
#        'Fruit, stone nes Production in tonnes',
#        'Grapes Production in tonnes', 'Linseed Production in tonnes',
#        'Maize Production in tonnes',
#        'Melons, other (inc.cantaloupes) Production in tonnes',
#        'Millet Production in tonnes', 'Nuts, nes Production in tonnes',
#        'Olives Production in tonnes', 'Oranges Production in tonnes',
#        'Peaches and nectarines Production in tonnes',
#        'Pears Production in tonnes', 'Pistachios Production in tonnes',
#        'Plums and sloes Production in tonnes',
#        'Potatoes Production in tonnes',
#        'Pulses, nes Production in tonnes',
#        'Rice, paddy Production in tonnes',
#        'Seed cotton Production in tonnes',
#        'Sesame seed Production in tonnes',
#        'Sugar beet Production in tonnes',
#        'Sugar cane Production in tonnes',
#        'Sunflower seed Production in tonnes',
#        'Vegetables, fresh nes Production in tonnes',
#        'Walnuts, with shell Production in tonnes',
#        'Watermelons Production in tonnes', 'Wheat Production in tonnes',
#        'Cereals (Rice Milled Eqv) Production in tonnes',
#        'Cereals,Total Production in tonnes',
#        'Citrus Fruit,Total Production in tonnes',
#        'Coarse Grain, Total Production in tonnes',
#        'Fibre Crops Primary Production in tonnes',
#        'Fruit excl Melons,Total Production in tonnes',
#        'Oilcakes Equivalent Production in tonnes',
#        'Oilcrops Primary Production in tonnes',
#        'Pulses,Total Production in tonnes',
#        'Roots and Tubers,Total Production in tonnes',
#        'Treenuts,Total Production in tonnes',
#        'Vegetables Primary Production in tonnes',
#        'Vegetables&Melons, Total Production in tonnes',
#        'Beans, dry Production in tonnes',
#        'Beans, green Production in tonnes',
#        'Broad beans, horse beans, dry Production in tonnes',
#        'Cabbages and other brassicas Production in tonnes',
#        'Carrots and turnips Production in tonnes',
#        'Cauliflowers and broccoli Production in tonnes',
#        'Cherries Production in tonnes',
#        'Cherries, sour Production in tonnes',
#        'Chestnut Production in tonnes',
#        'Chillies and peppers, green Production in tonnes',
#        'Cucumbers and gherkins Production in tonnes',
#        'Dates Production in tonnes',
#        'Eggplants (aubergines) Production in tonnes',
#        'Garlic Production in tonnes', 'Hops Production in tonnes',
#        'Leeks, other alliaceous vegetables Production in tonnes',
#        'Lemons and limes Production in tonnes',
#        'Lettuce and chicory Production in tonnes',
#        'Mushrooms and truffles Production in tonnes',
#        'Oats Production in tonnes', 'Oil, palm Production in tonnes',
#        'Okra Production in tonnes', 'Onions, dry Production in tonnes',
#        'Onions, shallots, green Production in tonnes',
#        'Peas, green Production in tonnes',
#        'Pumpkins, squash and gourds Production in tonnes',
#        'Quinces Production in tonnes', 'Rye Production in tonnes',
#        'Sorghum Production in tonnes', 'Soybeans Production in tonnes',
#        'Spices, nes Production in tonnes', 'Spinach Production in tonnes',
#        'Tangerines, mandarins, clementines, satsumas Production in tonnes',
#        'Tobacco, unmanufactured Production in tonnes',
#        'Tomatoes Production in tonnes',
#        'Vegetables, leguminous nes Production in tonnes',
#        'Vetches Production in tonnes', 'Artichokes Production in tonnes',
#        'Bananas Production in tonnes', 'Carobs Production in tonnes',
#        'Cassava Production in tonnes', 'Chick peas Production in tonnes',
#        'Chillies and peppers, dry Production in tonnes',
#        'Fruit, tropical fresh nes Production in tonnes',
#        'Grapefruit (inc. pomelos) Production in tonnes',
#        'Groundnuts, with shell Production in tonnes',
#        'Lentils Production in tonnes', 'Peas, dry Production in tonnes',
#        'Rapeseed Production in tonnes',
#        'Strawberries Production in tonnes',
#        'Triticale Production in tonnes',
#        'Cocoa, beans Production in tonnes',
#        'Coconuts Production in tonnes',
#        'Maize, green Production in tonnes',
#        'Pineapples Production in tonnes',
#        'Taro (cocoyam) Production in tonnes', 'Yams Production in tonnes',
#        'Bastfibres, other Production in tonnes',
#        'Cashew nuts, with shell Production in tonnes',
#        'Castor oil seed Production in tonnes',
#        'Coffee, green Production in tonnes',
#        'Flax fibre and tow Production in tonnes',
#        'Oil, palm fruit Production in tonnes',
#        'Palm kernels Production in tonnes', 'Sisal Production in tonnes',
#        'Sweet potatoes Production in tonnes',
#        'Jute & Jute-like Fibres Production in tonnes',
#        'Mangoes, mangosteens, guavas Production in tonnes',
#        'Asparagus Production in tonnes', 'Avocados Production in tonnes',
#        'Canary seed Production in tonnes',
#        'Cereals, nes Production in tonnes',
#        'Fibre crops nes Production in tonnes',
#        'Lupins Production in tonnes', 'Mat� Production in tonnes',
#        'Oilseeds nes Production in tonnes',
#        'Papayas Production in tonnes', 'Peppermint Production in tonnes',
#        'Safflower seed Production in tonnes',
#        'String beans Production in tonnes', 'Tea Production in tonnes',
#        'Tung nuts Production in tonnes',
#        'Hazelnuts, with shell Production in tonnes',
#        'Blueberries Production in tonnes',
#        'Cow peas, dry Production in tonnes',
#        'Currants Production in tonnes', 'Kiwi fruit Production in tonnes',
#        'Mustard seed Production in tonnes',
#        'Persimmons Production in tonnes',
#        'Raspberries Production in tonnes',
#        'Buckwheat Production in tonnes',
#        'Gooseberries Production in tonnes',
#        'Grain, mixed Production in tonnes',
#        'Hemp tow waste Production in tonnes',
#        'Poppy seed Production in tonnes',
#        'Cranberries Production in tonnes',
#        'Pigeon peas Production in tonnes',
#        'Plantains and others Production in tonnes',
#        'Areca nuts Production in tonnes', 'Coir Production in tonnes',
#        'Ginger Production in tonnes', 'Jute Production in tonnes',
#        'Rubber, natural Production in tonnes',
#        'Sugar crops, nes Production in tonnes',
#        'Fruit, pome nes Production in tonnes',
#        'Chicory roots Production in tonnes',
#        'Vanilla Production in tonnes',
#        'Roots and tubers, nes Production in tonnes',
#        'Yautia (cocoyam) Production in tonnes',
#        'Fonio Production in tonnes',
#        'Karite nuts (sheanuts) Production in tonnes',
#        'Kola nuts Production in tonnes', 'Melonseed Production in tonnes',
#        'Pepper (piper spp.) Production in tonnes',
#        'Nutmeg, mace and cardamoms Production in tonnes',
#        'Brazil nuts, with shell Production in tonnes',
#        'Pyrethrum, dried Production in tonnes',
#        'Quinoa Production in tonnes', 'Cashewapple Production in tonnes',
#        'Gums, natural Production in tonnes', 'Ramie Production in tonnes',
#        'Cassava leaves Production in tonnes',
#        'Hempseed Production in tonnes',
#        'Bambara beans Production in tonnes',
#        'Cinnamon (canella) Production in tonnes',
#        'Cloves Production in tonnes',
#        'Tallowtree seed Production in tonnes',
#        'Agave fibres nes Production in tonnes',
#        'Manila fibre (abaca) Production in tonnes',
#        'Kapok fibre Production in tonnes',
#        'Kapok fruit Production in tonnes',
#        'Kapokseed in shell Production in tonnes',
#        'Jojoba seed Production in tonnes'], dtype=object)

# %% [markdown]
# Now that we'll select only 10 crops to move forward with (This will make our work easier). If we want more we can change them later.

# %%
cropsincludes = ['Apples Production in tonnes',
                'Maize Production in tonnes',
                'Fruit, fresh nes Production in tonnes',
                'Potatoes Production in tonnes',
                'Rice, paddy Production in tonnes',
               'Vegetables Primary Production in tonnes',
               'Pulses, Total Production in tonnes',
               'Poppy seed Production in tonnes',
               'Sugar beet Production in tonnes',
               'Coffee, green Production in tonnes']
print("Total number of crops = ",len(cropsincludes))
cropsincludes
# Out:
# Total number of crops =  10
# ['Apples Production in tonnes',
#  'Maize Production in tonnes',
#  'Fruit, fresh nes Production in tonnes',
#  'Potatoes Production in tonnes',
#  'Rice, paddy Production in tonnes',
#  'Vegetables Primary Production in tonnes',
#  'Pulses, Total Production in tonnes',
#  'Poppy seed Production in tonnes',
#  'Sugar beet Production in tonnes',
#  'Coffee, green Production in tonnes']

# %%
selectcrops = cropsyield[cropsyield.typeName.isin(cropsincludes)].copy()
selectcrops.index = range(len(selectcrops))
selectcrops = selectarea[selectarea.code3.isin(countryincludes)]
## We also need to eliminate data from countries we don't need!
selectcrops
# Out:
#      code3                           typeName      1961      1962      1963  \
# 0      AFG              Apples yield in hg/ha   68018.0   68018.0   68018.0
# 1      AFG    Fruit, fresh nes yield in hg/ha   51153.0   50109.0   52129.0
# 2      AFG               Maize yield in hg/ha   14000.0   14000.0   14260.0
# 3      AFG            Potatoes yield in hg/ha   86667.0   76667.0   81333.0
# 4      AFG         Rice, paddy yield in hg/ha   15190.0   15190.0   15190.0
# ...    ...                                ...       ...       ...       ...
# 1103   VNM    Fruit, fresh nes yield in hg/ha   86000.0   86000.0   86000.0
# 1104   VNM               Maize yield in hg/ha   11230.0   11987.0    9307.0
# 1105   VNM            Potatoes yield in hg/ha  133333.0  150000.0  166667.0
# 1106   VNM         Rice, paddy yield in hg/ha   18966.0   19937.0   21400.0
# 1107   VNM  Vegetables Primary yield in hg/ha   88492.0   90183.0   90792.0
#
#           1964      1965      1966      1967      1968  ...      2005  \
# 0      78298.0   82258.0   83212.0   90196.0   93311.0  ...   72672.0
# 1      60544.0   63984.0   66607.0   71047.0   75299.0  ...   99235.0
# 2      14257.0   14400.0   14400.0   14144.0   17064.0  ...   12069.0
# 3      86000.0   88000.0   90667.0   98000.0  100000.0  ...  150000.0
# 4      17273.0   17273.0   15180.0   19223.0   19515.0  ...   30313.0
# ...        ...       ...       ...       ...       ...  ...       ...
# 1103   86000.0   88095.0   88095.0   88095.0   88095.0  ...  122222.0
# 1104   12436.0   11503.0    9589.0   11000.0   10962.0  ...   35979.0
# 1105  166667.0  137500.0  150000.0  180000.0  170000.0  ...  105714.0
# 1106   19441.0   19414.0   18079.0   19159.0   17095.0  ...   48891.0
# 1107   92730.0   93588.0   94498.0   91363.0   92909.0  ...  119130.0
#
#           2006      2007      2008      2009      2010      2011      2012  \
# 0      75000.0   85000.0   81919.0   85105.0   70000.0   70000.0   76519.0
# 1     103347.0  107886.0  120000.0  150000.0  120000.0   70000.0   73690.0
# 2      26204.0   26277.0   26277.0   21429.0   16448.0   16400.0   21986.0
# 3     150000.0  150400.0  140000.0  140000.0  120000.0  100000.0  109524.0
# 4      33750.0   32471.0   32211.0   32250.0   32308.0   32000.0   24390.0
# ...        ...       ...       ...       ...       ...       ...       ...
# 1103  121739.0  117391.0  117021.0  117441.0  117445.0  117367.0  116667.0
# 1104   37310.0   39259.0   31753.0   40137.0   40899.0   43128.0   43019.0
# 1105  105714.0  103333.0  105556.0  104865.0  120448.0  137810.0  146352.0
# 1106   48943.0   49869.0   52336.0   52372.0   53416.0   55383.0   56353.0
# 1107  125112.0  131937.0  139937.0  145971.0  148046.0  144662.0  155629.0
#
#           2013      2014
# 0      76005.0   73000.0
# 1      74902.0   75000.0
# 2      21972.0   24882.0
# 3     131960.0  136054.0
# 4      24980.0   24409.0
# ...        ...       ...
# 1103  116667.0  117521.0
# 1104   44354.0   44140.0
# 1105  135800.0  140954.0
# 1106   55728.0   57538.0
# 1107  165268.0  167622.0
#
# [138 rows x 56 columns]

# %% [markdown]
# **Wooho! Great so far.**
#
# Now, we'll go forward with this new data with selected parameters. And do similiar things with areayield.

# %%
areayield.typeName.unique()
# Out:
# array(['Almonds, with shell yield in hg/ha',
#        'Anise, badian, fennel, coriander yield in hg/ha',
#        'Apples yield in hg/ha', 'Apricots yield in hg/ha',
#        'Barley yield in hg/ha', 'Berries nes yield in hg/ha',
#        'Figs yield in hg/ha', 'Fruit, citrus nes yield in hg/ha',
#        'Fruit, fresh nes yield in hg/ha',
#        'Fruit, stone nes yield in hg/ha', 'Grapes yield in hg/ha',
#        'Linseed yield in hg/ha', 'Maize yield in hg/ha',
#        'Melons, other (inc.cantaloupes) yield in hg/ha',
#        'Millet yield in hg/ha', 'Nuts, nes yield in hg/ha',
#        'Olives yield in hg/ha', 'Oranges yield in hg/ha',
#        'Peaches and nectarines yield in hg/ha', 'Pears yield in hg/ha',
#        'Pistachios yield in hg/ha', 'Plums and sloes yield in hg/ha',
#        'Potatoes yield in hg/ha', 'Pulses, nes yield in hg/ha',
#        'Rice, paddy yield in hg/ha', 'Seed cotton yield in hg/ha',
#        'Sesame seed yield in hg/ha', 'Sugar beet yield in hg/ha',
#        'Sugar cane yield in hg/ha', 'Sunflower seed yield in hg/ha',
#        'Vegetables, fresh nes yield in hg/ha',
#        'Walnuts, with shell yield in hg/ha', 'Watermelons yield in hg/ha',
#        'Wheat yield in hg/ha', 'Cereals (Rice Milled Eqv) yield in hg/ha',
#        'Cereals,Total yield in hg/ha',
#        'Citrus Fruit,Total yield in hg/ha',
#        'Coarse Grain, Total yield in hg/ha',
#        'Fibre Crops Primary yield in hg/ha',
#        'Fruit excl Melons,Total yield in hg/ha',
#        'Oilcakes Equivalent yield in hg/ha',
#        'Oilcrops Primary yield in hg/ha', 'Pulses,Total yield in hg/ha',
#        'Roots and Tubers,Total yield in hg/ha',
#        'Treenuts,Total yield in hg/ha',
#        'Vegetables Primary yield in hg/ha',
#        'Vegetables&Melons, Total yield in hg/ha',
#        'Beans, dry yield in hg/ha', 'Beans, green yield in hg/ha',
#        'Broad beans, horse beans, dry yield in hg/ha',
#        'Cabbages and other brassicas yield in hg/ha',
#        'Carrots and turnips yield in hg/ha',
#        'Cauliflowers and broccoli yield in hg/ha',
#        'Cherries yield in hg/ha', 'Cherries, sour yield in hg/ha',
#        'Chestnut yield in hg/ha',
#        'Chillies and peppers, green yield in hg/ha',
#        'Cucumbers and gherkins yield in hg/ha', 'Dates yield in hg/ha',
#        'Eggplants (aubergines) yield in hg/ha', 'Garlic yield in hg/ha',
#        'Hops yield in hg/ha',
#        'Leeks, other alliaceous vegetables yield in hg/ha',
#        'Lemons and limes yield in hg/ha',
#        'Lettuce and chicory yield in hg/ha', 'Oats yield in hg/ha',
#        'Okra yield in hg/ha', 'Onions, dry yield in hg/ha',
#        'Onions, shallots, green yield in hg/ha',
#        'Peas, green yield in hg/ha',
#        'Pumpkins, squash and gourds yield in hg/ha',
#        'Quinces yield in hg/ha', 'Rye yield in hg/ha',
#        'Sorghum yield in hg/ha', 'Soybeans yield in hg/ha',
#        'Spices, nes yield in hg/ha', 'Spinach yield in hg/ha',
#        'Tangerines, mandarins, clementines, satsumas yield in hg/ha',
#        'Tobacco, unmanufactured yield in hg/ha',
#        'Tomatoes yield in hg/ha',
#        'Vegetables, leguminous nes yield in hg/ha',
#        'Vetches yield in hg/ha', 'Artichokes yield in hg/ha',
#        'Bananas yield in hg/ha', 'Carobs yield in hg/ha',
#        'Chick peas yield in hg/ha',
#        'Chillies and peppers, dry yield in hg/ha',
#        'Grapefruit (inc. pomelos) yield in hg/ha',
#        'Groundnuts, with shell yield in hg/ha', 'Lentils yield in hg/ha',
#        'Peas, dry yield in hg/ha', 'Rapeseed yield in hg/ha',
#        'Triticale yield in hg/ha', 'Cassava yield in hg/ha',
#        'Cocoa, beans yield in hg/ha', 'Coconuts yield in hg/ha',
#        'Maize, green yield in hg/ha', 'Taro (cocoyam) yield in hg/ha',
#        'Yams yield in hg/ha', 'Bastfibres, other yield in hg/ha',
#        'Cashew nuts, with shell yield in hg/ha',
#        'Castor oil seed yield in hg/ha', 'Coffee, green yield in hg/ha',
#        'Oil, palm fruit yield in hg/ha', 'Pineapples yield in hg/ha',
#        'Sisal yield in hg/ha', 'Sweet potatoes yield in hg/ha',
#        'Jute & Jute-like Fibres yield in hg/ha',
#        'Fruit, tropical fresh nes yield in hg/ha',
#        'Mangoes, mangosteens, guavas yield in hg/ha',
#        'Asparagus yield in hg/ha', 'Avocados yield in hg/ha',
#        'Canary seed yield in hg/ha', 'Cereals, nes yield in hg/ha',
#        'Fibre crops nes yield in hg/ha',
#        'Flax fibre and tow yield in hg/ha', 'Lupins yield in hg/ha',
#        'Mat� yield in hg/ha', 'Papayas yield in hg/ha',
#        'Safflower seed yield in hg/ha', 'Strawberries yield in hg/ha',
#        'String beans yield in hg/ha', 'Tea yield in hg/ha',
#        'Tung nuts yield in hg/ha', 'Hazelnuts, with shell yield in hg/ha',
#        'Cow peas, dry yield in hg/ha', 'Currants yield in hg/ha',
#        'Kiwi fruit yield in hg/ha',
#        'Mushrooms and truffles yield in hg/ha',
#        'Mustard seed yield in hg/ha', 'Persimmons yield in hg/ha',
#        'Raspberries yield in hg/ha', 'Buckwheat yield in hg/ha',
#        'Gooseberries yield in hg/ha', 'Grain, mixed yield in hg/ha',
#        'Hemp tow waste yield in hg/ha', 'Oilseeds nes yield in hg/ha',
#        'Poppy seed yield in hg/ha', 'Cranberries yield in hg/ha',
#        'Pigeon peas yield in hg/ha',
#        'Plantains and others yield in hg/ha', 'Areca nuts yield in hg/ha',
#        'Ginger yield in hg/ha', 'Jute yield in hg/ha',
#        'Rubber, natural yield in hg/ha',
#        'Sugar crops, nes yield in hg/ha', 'Chicory roots yield in hg/ha',
#        'Roots and tubers, nes yield in hg/ha',
#        'Yautia (cocoyam) yield in hg/ha', 'Fonio yield in hg/ha',
#        'Karite nuts (sheanuts) yield in hg/ha',
#        'Kola nuts yield in hg/ha', 'Pepper (piper spp.) yield in hg/ha',
#        'Nutmeg, mace and cardamoms yield in hg/ha',
#        'Quinoa yield in hg/ha', 'Cashewapple yield in hg/ha',
#        'Ramie yield in hg/ha', 'Blueberries yield in hg/ha',
#        'Hempseed yield in hg/ha', 'Peppermint yield in hg/ha',
#        'Bambara beans yield in hg/ha', 'Melonseed yield in hg/ha',
#        'Cinnamon (canella) yield in hg/ha', 'Cloves yield in hg/ha',
#        'Tallowtree seed yield in hg/ha', 'Vanilla yield in hg/ha',
#        'Agave fibres nes yield in hg/ha', 'Cassava leaves yield in hg/ha',
#        'Manila fibre (abaca) yield in hg/ha',
#        'Pyrethrum, dried yield in hg/ha', 'Kapok fruit yield in hg/ha',
#        'Jojoba seed yield in hg/ha', 'Cotton lint yield in hg/ha',
#        'Brazil nuts, with shell yield in hg/ha',
#        'Fruit, pome nes yield in hg/ha'], dtype=object)

# %%
areaincludes = ['Apples yield in hg/ha',
                'Maize yield in hg/ha',
                'Fruit, fresh nes yield in hg/ha',
                'Potatoes yield in hg/ha',
                'Rice, paddy yield in hg/ha',
               'Vegetables Primary yield in hg/ha',
               'Pulses, Total yield in hg/ha',
               'Poppy seed yield in hg/ha',
               'Sugar beet yield in hg/ha',
               'Coffee, green yield in hg/ha']
print("Total number of crops = ", len(areaincludes))
areaincludes
# Out:
# Total number of crops =  10
# ['Apples yield in hg/ha',
#  'Maize yield in hg/ha',
#  'Fruit, fresh nes yield in hg/ha',
#  'Potatoes yield in hg/ha',
#  'Rice, paddy yield in hg/ha',
#  'Vegetables Primary yield in hg/ha',
#  'Pulses, Total yield in hg/ha',
#  'Poppy seed yield in hg/ha',
#  'Sugar beet yield in hg/ha',
#  'Coffee, green yield in hg/ha']

# %%
selectarea = areayield[areayield.typeName.isin(areaincludes)]
selectarea.index = range(len(selectarea))
selectarea = selectarea[selectarea.code3.isin(countryincludes)]
selectarea
# Out:
#      code3                           typeName      1961      1962      1963  \
# 0      AFG              Apples yield in hg/ha   68018.0   68018.0   68018.0
# 1      AFG    Fruit, fresh nes yield in hg/ha   51153.0   50109.0   52129.0
# 2      AFG               Maize yield in hg/ha   14000.0   14000.0   14260.0
# 3      AFG            Potatoes yield in hg/ha   86667.0   76667.0   81333.0
# 4      AFG         Rice, paddy yield in hg/ha   15190.0   15190.0   15190.0
# ...    ...                                ...       ...       ...       ...
# 1103   VNM    Fruit, fresh nes yield in hg/ha   86000.0   86000.0   86000.0
# 1104   VNM               Maize yield in hg/ha   11230.0   11987.0    9307.0
# 1105   VNM            Potatoes yield in hg/ha  133333.0  150000.0  166667.0
# 1106   VNM         Rice, paddy yield in hg/ha   18966.0   19937.0   21400.0
# 1107   VNM  Vegetables Primary yield in hg/ha   88492.0   90183.0   90792.0
#
#           1964      1965      1966      1967      1968  ...      2005  \
# 0      78298.0   82258.0   83212.0   90196.0   93311.0  ...   72672.0
# 1      60544.0   63984.0   66607.0   71047.0   75299.0  ...   99235.0
# 2      14257.0   14400.0   14400.0   14144.0   17064.0  ...   12069.0
# 3      86000.0   88000.0   90667.0   98000.0  100000.0  ...  150000.0
# 4      17273.0   17273.0   15180.0   19223.0   19515.0  ...   30313.0
# ...        ...       ...       ...       ...       ...  ...       ...
# 1103   86000.0   88095.0   88095.0   88095.0   88095.0  ...  122222.0
# 1104   12436.0   11503.0    9589.0   11000.0   10962.0  ...   35979.0
# 1105  166667.0  137500.0  150000.0  180000.0  170000.0  ...  105714.0
# 1106   19441.0   19414.0   18079.0   19159.0   17095.0  ...   48891.0
# 1107   92730.0   93588.0   94498.0   91363.0   92909.0  ...  119130.0
#
#           2006      2007      2008      2009      2010      2011      2012  \
# 0      75000.0   85000.0   81919.0   85105.0   70000.0   70000.0   76519.0
# 1     103347.0  107886.0  120000.0  150000.0  120000.0   70000.0   73690.0
# 2      26204.0   26277.0   26277.0   21429.0   16448.0   16400.0   21986.0
# 3     150000.0  150400.0  140000.0  140000.0  120000.0  100000.0  109524.0
# 4      33750.0   32471.0   32211.0   32250.0   32308.0   32000.0   24390.0
# ...        ...       ...       ...       ...       ...       ...       ...
# 1103  121739.0  117391.0  117021.0  117441.0  117445.0  117367.0  116667.0
# 1104   37310.0   39259.0   31753.0   40137.0   40899.0   43128.0   43019.0
# 1105  105714.0  103333.0  105556.0  104865.0  120448.0  137810.0  146352.0
# 1106   48943.0   49869.0   52336.0   52372.0   53416.0   55383.0   56353.0
# 1107  125112.0  131937.0  139937.0  145971.0  148046.0  144662.0  155629.0
#
#           2013      2014
# 0      76005.0   73000.0
# 1      74902.0   75000.0
# 2      21972.0   24882.0
# 3     131960.0  136054.0
# 4      24980.0   24409.0
# ...        ...       ...
# 1103  116667.0  117521.0
# 1104   44354.0   44140.0
# 1105  135800.0  140954.0
# 1106   55728.0   57538.0
# 1107  165268.0  167622.0
#
# [138 rows x 56 columns]

# %% [markdown]
# We are done with cleaning and selecting the crop production and yield for the crops (10) we need and for the countries (22) we need.
#
# **Now let us come to cleaning emissions data.**

# %%
emissionall
# Out:
#      code3                                           typeName       1961  \
# 0      AFG  Cereals excluding rice Emissions (CO2eq) gigag...   402.2165
# 1      AFG            Rice, paddy Emissions (CO2eq) gigagrams   665.5675
# 2      AFG           Meat, cattle Emissions (CO2eq) gigagrams  1576.9262
# 3      AFG  Milk, whole fresh cow Emissions (CO2eq) gigagrams  1172.1377
# 4      AFG             Meat, goat Emissions (CO2eq) gigagrams   717.8808
# ...    ...                                                ...        ...
# 1982   VNM          Meat, buffalo Emissions (CO2eq) gigagrams  3959.0307
# 1983   VNM  Milk, whole fresh buffalo Emissions (CO2eq) gi...    14.1142
# 1984   VNM          Meat, chicken Emissions (CO2eq) gigagrams    85.7415
# 1985   VNM    Eggs, hen, in shell Emissions (CO2eq) gigagrams    84.5900
# 1986   VNM              Meat, pig Emissions (CO2eq) gigagrams  1349.4545
#
#            1962       1963       1964       1965       1966       1967  \
# 0      408.3269   385.7396   406.7923   410.0940   392.3671   410.4523
# 1      665.5675   665.5675   699.3576   699.3576   703.5647   660.1999
# 2     1791.9616  1806.2973  1842.1366  1813.4652  1892.3115  1820.6330
# 3     1172.1377  1306.0963  1306.0963  1456.7998  1607.5032  1774.9514
# 4      693.8384   607.4048   543.4226   454.2740   454.2740   428.6811
# ...         ...        ...        ...        ...        ...        ...
# 1982  3987.9648  4135.1052  4197.7369  4118.5210  4239.9031  4054.4779
# 1983    14.1142    14.1142    14.1142    17.6427    17.6427    21.1713
# 1984    94.4821   135.6879   107.8011   124.8662   109.4660   107.8011
# 1985    86.3898    88.1896    91.1892    95.9886    98.9883   101.9879
# 1986  1355.5942  1470.1958  1549.0702  1556.3588  1575.0792  1546.0381
#
#            1968  ...       2005       2006       2007       2008       2009  \
# 0      415.6880  ...   540.4174   513.3178   558.5772   399.9802   622.9562
# 1      662.6412  ...   528.8122   541.7134   564.2252   626.8125   664.4793
# 2     1829.9512  ...   804.9492   938.9879   972.6768  1035.7538  1018.5510
# 3     1808.4411  ...  4353.6544  4688.5509  5023.4474  5525.7922  5525.7922
# 4      407.9935  ...  1008.1470   969.5444   666.9083   879.9692   757.1233
# ...         ...  ...        ...        ...        ...        ...        ...
# 1982  4059.4179  ...  5099.0251  5096.3871  5228.2493  5055.8798  5034.5320
# 1983    21.1713  ...    56.4568    57.0570    58.2210    56.4568    58.2210
# 1984   118.6229  ...   440.9317   395.5095   446.1885   504.0848   566.0580
# 1985    95.9886  ...   287.9659   331.1368   305.9638   311.9631   383.9545
# 1986  1648.7745  ...  5166.9377  5057.7800  5002.2966  5028.8330  5203.2496
#
#            2010       2011       2012       2013       2014
# 0      569.4834   502.1896   930.8129   765.7361   754.5742
# 1      689.6050   703.0602   752.4373   708.0396   747.5037
# 2     1270.8592  1235.7367   891.6801   856.5577   875.2105
# 3     6530.4817  6363.0334  6697.9299  6764.9092  6912.2253
# 4      970.1842  1116.4903  1068.7168  1026.0620  1032.4997
# ...         ...        ...        ...        ...        ...
# 1982  5019.3593  4728.2541  4579.7252  4461.0354  4375.0942
# 1983    56.4568    56.4568    56.4568    54.6925    56.5855
# 1984   630.9963   648.5550   635.7599   678.4771   711.6590
# 1985   399.5527   419.9503   425.9496   428.9492   449.9276
# 1986  5155.3373  5095.5787  4989.7200  4946.4946  5040.1331
#
# [223 rows x 56 columns]

# %% [markdown]
# First let us segregate country wise.

# %%
countryemission = emissionall[emissionall.code3.isin(countryincludes)]
countryemission
# Out:
#      code3                                           typeName       1961  \
# 0      AFG  Cereals excluding rice Emissions (CO2eq) gigag...   402.2165
# 1      AFG            Rice, paddy Emissions (CO2eq) gigagrams   665.5675
# 2      AFG           Meat, cattle Emissions (CO2eq) gigagrams  1576.9262
# 3      AFG  Milk, whole fresh cow Emissions (CO2eq) gigagrams  1172.1377
# 4      AFG             Meat, goat Emissions (CO2eq) gigagrams   717.8808
# ...    ...                                                ...        ...
# 1982   VNM          Meat, buffalo Emissions (CO2eq) gigagrams  3959.0307
# 1983   VNM  Milk, whole fresh buffalo Emissions (CO2eq) gi...    14.1142
# 1984   VNM          Meat, chicken Emissions (CO2eq) gigagrams    85.7415
# 1985   VNM    Eggs, hen, in shell Emissions (CO2eq) gigagrams    84.5900
# 1986   VNM              Meat, pig Emissions (CO2eq) gigagrams  1349.4545
#
#            1962       1963       1964       1965       1966       1967  \
# 0      408.3269   385.7396   406.7923   410.0940   392.3671   410.4523
# 1      665.5675   665.5675   699.3576   699.3576   703.5647   660.1999
# 2     1791.9616  1806.2973  1842.1366  1813.4652  1892.3115  1820.6330
# 3     1172.1377  1306.0963  1306.0963  1456.7998  1607.5032  1774.9514
# 4      693.8384   607.4048   543.4226   454.2740   454.2740   428.6811
# ...         ...        ...        ...        ...        ...        ...
# 1982  3987.9648  4135.1052  4197.7369  4118.5210  4239.9031  4054.4779
# 1983    14.1142    14.1142    14.1142    17.6427    17.6427    21.1713
# 1984    94.4821   135.6879   107.8011   124.8662   109.4660   107.8011
# 1985    86.3898    88.1896    91.1892    95.9886    98.9883   101.9879
# 1986  1355.5942  1470.1958  1549.0702  1556.3588  1575.0792  1546.0381
#
#            1968  ...       2005       2006       2007       2008       2009  \
# 0      415.6880  ...   540.4174   513.3178   558.5772   399.9802   622.9562
# 1      662.6412  ...   528.8122   541.7134   564.2252   626.8125   664.4793
# 2     1829.9512  ...   804.9492   938.9879   972.6768  1035.7538  1018.5510
# 3     1808.4411  ...  4353.6544  4688.5509  5023.4474  5525.7922  5525.7922
# 4      407.9935  ...  1008.1470   969.5444   666.9083   879.9692   757.1233
# ...         ...  ...        ...        ...        ...        ...        ...
# 1982  4059.4179  ...  5099.0251  5096.3871  5228.2493  5055.8798  5034.5320
# 1983    21.1713  ...    56.4568    57.0570    58.2210    56.4568    58.2210
# 1984   118.6229  ...   440.9317   395.5095   446.1885   504.0848   566.0580
# 1985    95.9886  ...   287.9659   331.1368   305.9638   311.9631   383.9545
# 1986  1648.7745  ...  5166.9377  5057.7800  5002.2966  5028.8330  5203.2496
#
#            2010       2011       2012       2013       2014
# 0      569.4834   502.1896   930.8129   765.7361   754.5742
# 1      689.6050   703.0602   752.4373   708.0396   747.5037
# 2     1270.8592  1235.7367   891.6801   856.5577   875.2105
# 3     6530.4817  6363.0334  6697.9299  6764.9092  6912.2253
# 4      970.1842  1116.4903  1068.7168  1026.0620  1032.4997
# ...         ...        ...        ...        ...        ...
# 1982  5019.3593  4728.2541  4579.7252  4461.0354  4375.0942
# 1983    56.4568    56.4568    56.4568    54.6925    56.5855
# 1984   630.9963   648.5550   635.7599   678.4771   711.6590
# 1985   399.5527   419.9503   425.9496   428.9492   449.9276
# 1986  5155.3373  5095.5787  4989.7200  4946.4946  5040.1331
#
# [223 rows x 56 columns]

# %% [markdown]
# Fine, now let us create a new array that contains cumulative figures of emissions for every country for every year.
